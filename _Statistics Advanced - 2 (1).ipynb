# %% [raw]
#                                               Statistics Advanced - 2 || Assignment
#                                    _______________________________________________________
#
# Question 1: What is hypothesis testing in statistics?
# ANS:-Hypothesis testing is a method to decide if a claim about data is true or false
# using sample information .
#
# A school claims that the average height of students is 160 cm.
# You think it might be different, so you want to test the claim.
#
# Step 1 – State the Hypotheses
#
# H₀ (Null): Average height = 160 cm
# H₁ (Alternative): Average height ≠ 160 cm
#
# Step 2 – Collect Data
# You randomly check 30 students and find:
#
# Sample mean = 162 cm
# Sample standard deviation = 5 cm
#
# Step 3 – Run the Test
# Using a t-test or z-test, you calculate the p-value.
# Let’s say your p-value = 0.03 (3%).
#
# Step 4 – Make Decision
#
# If p-value < 0.05, reject H₀.
# Here, 0.03 < 0.05, so reject H₀.
#
# Step 5 – Conclusion
# The average height is not 160 cm. The school’s claim is likely false.
#
# Question 2: What is the null hypothesis, and how does it differ from the alternative
# hypothesis?
# ANS:-Null Hypothesis (H₀):
# It is the default assumption that there is no effect, no difference, or nothing new happening.
#
# Alternative Hypothesis (H₁):
# It is the opposite claim, saying there is an effect, a difference, or something new happening.
#
# Example:
# A company says a packet weighs 50 g.
#
# H₀: Mean weight = 50 g (claim is correct)
# H₁: Mean weight ≠ 50 g (claim is wrong or different)
# In testing, if evidence is strong (like p-value < 0.05), we reject H₀ and support H₁.
#
# Question 3: Explain the significance level in hypothesis testing and its role in deciding
# the outcome of a test.
# ANS:-Significance Level (α) is the limit or cut off we set to decide if our test result is strong enough to
# say the claim is wrong.
#
# Key Points
#
# Common values: 0.05 (5%), 0.01 (1%), or 0.10 (10%).
#
# It decides how strict your test is.
# Role in Decision Making
# If p-value ≤ α → Reject H₀ (there is strong evidence against the null).
# If p-value > α → Fail to reject H₀ (not enough evidence against the null).
#
# Example
# A medicine test uses α = 0.05 (5% risk).
# If the p-value = 0.03 (3%) → Reject H₀ → Medicine is effective.
# If the p-value = 0.08 (8%) → Fail to reject H₀ → Not enough proof that medicine works.
#
# Question 4: What are Type I and Type II errors? Give examples of each.
# ANS:-1. Type I Error (False Positive)
#
# Meaning: You reject the null hypothesis (H₀) even though it is actually true.
#
# Think: A “false alarm.”
#
# Example:
# A court declares an innocent person guilty.
# H₀: The person is innocent.
# You rejected H₀ → Wrong decision.
#
# 2. Type II Error (False Negative)
#
# Meaning: You fail to reject the null hypothesis (H₀) even though it is actually false.
#
# Think: You miss the real effect.
#
# Example:
# A court declares a guilty person not guilty.
# H₀: The person is innocent.
# You failed to reject H₀ → Wrong decision.
#
# Type| - Flase Alarm
# Type|| - Missed Danger
#
# Question 5: What is the difference between a Z-test and a T-test? Explain when to use
# each.
# Ans:-1. Z-Test
#
# Used when:
#
# Population variance (σ) is known
# Sample size is large (n > 30)
# Purpose: Test population mean or proportion.
# Example:
# Testing if the average height of 100 students (large sample) is 160 cm when population standard deviation is known.
#
# 2. T-Test
#
# Used when:
# Population variance (σ) is unknown
# Sample size is small (n ≤ 30)
# Purpose: Test population mean or compare two groups.
# Example:
# Testing if the average marks of 20 students differ from 50 when population standard deviation is unknown.
#
# Question 6: Write a Python program to generate a binomial distribution with n=10 and
# p=0.5, then plot its histogram..
# ANS:-

# %%
import numpy as np
import matplotlib.pyplot as  plt
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10   # number of trials
p = 0.5  # probability of success
size = 1000  # number of random samples

# Generate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=range(n+2), edgecolor='black', align='left')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.title('Binomial Distribution (n=10, p=0.5)')
plt.show()

# %% [raw]
# Question 7: Implement hypothesis testing using Z-statistics for a sample dataset in
# Python. Show the Python code and interpret the results.
# sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
# 50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
# 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
# 50.3, 50.4, 50.0, 49.7, 50.5, 49.9
# ANS:-Population mean claim (μ₀) = 50
# Population standard deviation (σ) = 0.5 (assumed known)
# Significance level (α) = 0.05

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample_data = [
    49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
    50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
    50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
    50.3, 50.4, 50.0, 49.7, 50.5, 49.9
]

# Given values
mu_0 = 50   # population mean
sigma = 0.5 # population standard deviation
alpha = 0.05

# Sample statistics
sample_mean = np.mean(sample_data)
n = len(sample_data)

# Z-statistic
z_stat = (sample_mean - mu_0) / (sigma / np.sqrt(n))

# P-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Statistic: {z_stat:.2f}")
print(f"P-Value: {p_value:.4f}")

# Decision
if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from 50.")
else:
    print("Fail to reject the null hypothesis: No significant difference from 50.")
# Out:
# Sample Mean: 50.09
# Z-Statistic: 1.07
# P-Value: 0.2861
# Fail to reject the null hypothesis: No significant difference from 50.

# %% [raw]
# Question 8: Write a Python script to simulate data from a normal distribution and
# calculate the 95% confidence interval for its mean. Plot the data using Matplotlib
# ANS:-

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate data
np.random.seed(42)  # for reproducibility
data = np.random.normal(loc=50, scale=5, size=100)  # mean=50, sd=5, n=100

# Step 2: Calculate statistics
mean = np.mean(data)
std_err = stats.sem(data)  # standard error of mean
confidence_level = 0.95
confidence_interval = stats.t.interval(confidence_level, len(data)-1, loc=mean, scale=std_err)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: {confidence_interval}")

# Step 3: Plot data
plt.figure(figsize=(8,5))
plt.hist(data, bins=15, edgecolor='black', alpha=0.7)
plt.axvline(mean, color='red', linestyle='--', label=f"Mean = {mean:.2f}")
plt.axvline(confidence_interval[0], color='green', linestyle='--', label=f"Lower CI = {confidence_interval[0]:.2f}")
plt.axvline(confidence_interval[1], color='green', linestyle='--', label=f"Upper CI = {confidence_interval[1]:.2f}")

plt.title("Normal Distribution with 95% Confidence Interval")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Sample Mean: 49.48
# 95% Confidence Interval: (np.float64(48.579765818190495), np.float64(50.38176900786857))

# %% [raw]
# Question 9: Write a Python function to calculate the Z-scores from a dataset and
# visualize the standardized data using a histogram. Explain what the Z-scores represent
# in terms of standard deviations from the mean.
# (Include your Python code and output in the code box below.)
# ANS:-

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate Z-scores
def calculate_z_scores(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores, mean, std_dev

# Sample dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=5, size=100)

# Calculate Z-scores
z_scores, mean, std_dev = calculate_z_scores(data)

print(f"Original Mean: {mean:.2f}")
print(f"Original Std Dev: {std_dev:.2f}")
print(f"First 5 Z-scores: {z_scores[:5]}")

# Plot histogram of Z-scores
plt.figure(figsize=(8,5))
plt.hist(z_scores, bins=15, edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label="Mean (Z=0)")
plt.axvline(1, color='green', linestyle='--', label="Z=+1 (1 Std Dev)")
plt.axvline(-1, color='green', linestyle='--', label="Z=-1 (1 Std Dev)")
plt.title("Histogram of Z-Scores")
plt.xlabel("Z-Score")
plt.ylabel("Frequency")
plt.legend()
plt.show()
